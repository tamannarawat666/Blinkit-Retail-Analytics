# %%
import pandas as pd
import numpy as np

# %%
df=pd.read_csv("/Users/tamannarawat/Downloads/blinkit_clean.csv")

# %%
df.head()
# Out:
#   Item Fat Content Item Identifier              Item Type  \
# 0          Regular           FDX32  Fruits and Vegetables
# 1          Low Fat           NCB42     Health and Hygiene
# 2          Regular           FDR28           Frozen Foods
# 3          Regular           FDL50                 Canned
# 4          Low Fat           DRI25            Soft Drinks
#
#    Outlet Establishment Year Outlet Identifier Outlet Location Type  \
# 0                       2012            OUT049               Tier 1
# 1                       2022            OUT018               Tier 3
# 2                       2016            OUT046               Tier 1
# 3                       2014            OUT013               Tier 3
# 4                       2015            OUT045               Tier 2
#
#   Outlet Size        Outlet Type  Item Visibility  Item Weight     Sales  \
# 0      Medium  Supermarket Type1         0.100014        15.10  145.4786
# ...

# %%
df.tail()
# Out:
#      Item Fat Content Item Identifier           Item Type  \
# 8518          low fat           NCT53  Health and Hygiene
# 8519          low fat           FDN09         Snack Foods
# 8520          low fat           DRE13         Soft Drinks
# 8521              reg           FDT50               Dairy
# 8522              reg           FDM58         Snack Foods
#
#       Outlet Establishment Year Outlet Identifier Outlet Location Type  \
# 8518                       2018            OUT027               Tier 3
# 8519                       2018            OUT027               Tier 3
# 8520                       2018            OUT027               Tier 3
# 8521                       2018            OUT027               Tier 3
# 8522                       2018            OUT027               Tier 3
#
#      Outlet Size        Outlet Type  Item Visibility  Item Weight     Sales  \
# 8518      Medium  Supermarket Type3         0.000000          NaN  164.5526
# ...

# %%
df.shape
# Out:
# (8523, 12)

# %%
df.columns
# Out:
# Index(['Item Fat Content', 'Item Identifier', 'Item Type',
#        'Outlet Establishment Year', 'Outlet Identifier',
#        'Outlet Location Type', 'Outlet Size', 'Outlet Type', 'Item Visibility',
#        'Item Weight', 'Sales', 'Rating'],
#       dtype='object')

# %%
df.describe
# Out:
# <bound method NDFrame.describe of      Item Fat Content Item Identifier              Item Type  \
# 0             Regular           FDX32  Fruits and Vegetables
# 1             Low Fat           NCB42     Health and Hygiene
# 2             Regular           FDR28           Frozen Foods
# 3             Regular           FDL50                 Canned
# 4             Low Fat           DRI25            Soft Drinks
# ...               ...             ...                    ...
# 8518          low fat           NCT53     Health and Hygiene
# 8519          low fat           FDN09            Snack Foods
# 8520          low fat           DRE13            Soft Drinks
# 8521              reg           FDT50                  Dairy
# 8522              reg           FDM58            Snack Foods
#
#       Outlet Establishment Year Outlet Identifier Outlet Location Type  \
# 0                          2012            OUT049               Tier 1
# ...

# %%
df.isnull().sum()
# Out:
# Item Fat Content                0
# Item Identifier                 0
# Item Type                       0
# Outlet Establishment Year       0
# Outlet Identifier               0
# Outlet Location Type            0
# Outlet Size                     0
# Outlet Type                     0
# Item Visibility                 0
# Item Weight                  1463
# Sales                           0
# Rating                          0
# dtype: int64

# %%
(df.isnull().sum()/len(df))*100
# Out:
# Item Fat Content              0.000000
# Item Identifier               0.000000
# Item Type                     0.000000
# Outlet Establishment Year     0.000000
# Outlet Identifier             0.000000
# Outlet Location Type          0.000000
# Outlet Size                   0.000000
# Outlet Type                   0.000000
# Item Visibility               0.000000
# Item Weight                  17.165317
# Sales                         0.000000
# Rating                        0.000000
# dtype: float64

# %%
df.duplicated().all()
# Out:
# np.False_

# %%
df.nunique()
# Out:
# Item Fat Content                5
# Item Identifier              1559
# Item Type                      16
# Outlet Establishment Year       9
# Outlet Identifier              10
# Outlet Location Type            3
# Outlet Size                     3
# Outlet Type                     4
# Item Visibility              7880
# Item Weight                   415
# Sales                        5938
# Rating                         39
# dtype: int64

# %%
df.dtypes
# Out:
# Item Fat Content              object
# Item Identifier               object
# Item Type                     object
# Outlet Establishment Year      int64
# Outlet Identifier             object
# Outlet Location Type          object
# Outlet Size                   object
# Outlet Type                   object
# Item Visibility              float64
# Item Weight                  float64
# Sales                        float64
# Rating                       float64
# dtype: object

# %%
df['Sales'].sum()
# Out:
# np.float64(1201681.4928)

# %%
df['Sales'].mean()
# Out:
# np.float64(140.99278338613163)

# %%
df.groupby("Item Type")['Sales'].sum().sort_values(ascending=False)
# Out:
# Item Type
# Fruits and Vegetables    178124.0810
# Snack Foods              175433.9224
# Household                135976.5254
# Frozen Foods             118558.8814
# Dairy                    101276.4616
# Canned                    90706.7290
# Baking Goods              81894.7364
# Health and Hygiene        68025.8388
# Meat                      59449.8638
# Soft Drinks               58514.1670
# Breads                    35379.1198
# Hard Drinks               29334.6806
# Others                    22451.8916
# Starchy Foods             21880.0274
# Breakfast                 15596.6966
# Seafood                    9077.8700
# Name: Sales, dtype: float64

# %%
df.groupby("Outlet Identifier")["Sales"].sum().sort_values(ascending=False)
# Out:
# Outlet Identifier
# OUT035    133103.9070
# OUT046    132113.3698
# OUT013    131809.0156
# OUT018    131477.7764
# OUT045    130942.7802
# OUT027    130714.6746
# OUT049    130476.8598
# OUT017    129103.9604
# OUT010     78131.5666
# OUT019     73807.5824
# Name: Sales, dtype: float64

# %%
df.groupby("Outlet Type")["Sales"].sum().sort_values(ascending=False)
# Out:
# Outlet Type
# Supermarket Type1    787549.8928
# Grocery Store        151939.1490
# Supermarket Type2    131477.7764
# Supermarket Type3    130714.6746
# Name: Sales, dtype: float64

# %%
df.groupby("Outlet Size")["Sales"].sum().sort_values(ascending=False)
# Out:
# Outlet Size
# Medium    507895.7364
# Small     444794.1704
# High      248991.5860
# Name: Sales, dtype: float64

# %%
df.groupby("Item Fat Content")["Sales"].sum().sort_values(ascending=False)
# Out:
# Item Fat Content
# Low Fat    717390.8474
# Regular    409413.1234
# LF          43857.1082
# reg         15948.6810
# low fat     15071.7328
# Name: Sales, dtype: float64

# %%
df.groupby("Item Type")["Rating"].mean().sort_values(ascending=False)
# Out:
# Item Type
# Meat                     4.023059
# Household                3.998681
# Canned                   3.994299
# Health and Hygiene       3.986154
# Baking Goods             3.983025
# Frozen Foods             3.971145
# Dairy                    3.965836
# Seafood                  3.959375
# Fruits and Vegetables    3.956169
# Others                   3.954438
# Snack Foods              3.948917
# Breakfast                3.932727
# Soft Drinks              3.920674
# Starchy Foods            3.920270
# Hard Drinks              3.907477
# Breads                   3.881275
# Name: Rating, dtype: float64

# %%
df.groupby("Item Identifier")["Sales"].sum().sort_values(ascending=False).head(10)
# Out:
# Item Identifier
# FDU12    2371.0112
# FDT07    2306.8970
# NCQ06    2294.7126
# FDL58    2111.6544
# NCB31    2104.7280
# FDX31    2104.4622
# FDF05    2103.1280
# FDR59    2096.5752
# FDP28    2087.8488
# FDA04    2072.0696
# Name: Sales, dtype: float64

# %%
df.groupby("Outlet Identifier")["Sales"].sum().idxmax()
# Out:
# 'OUT035'

# %% [markdown]
# # Numpy

# %%
np.mean(df['Sales'])
# Out:
# np.float64(140.99278338613163)

# %%
np.median(df['Sales'])
# Out:
# np.float64(143.0128)

# %%
np.std(df['Sales'])
# Out:
# np.float64(62.27141334999408)

# %%
np.min(df['Sales'])
# Out:
# np.float64(31.29)

# %%
np.max(df['Sales'])
# Out:
# np.float64(266.8884)

# %%
np.percentile(df['Sales'],25)
# Out:
# np.float64(93.8265)

# %%
np.percentile(df['Sales'],50)
# Out:
# np.float64(143.0128)

# %%
np.percentile(df['Sales'],75)
# Out:
# np.float64(185.6437)

# %% [markdown]
# # pandas analysis

# %%
avg_sales=df['Sales'].mean()
df[df['Sales']>avg_sales]
# Out:
#      Item Fat Content Item Identifier              Item Type  \
# 0             Regular           FDX32  Fruits and Vegetables
# 2             Regular           FDR28           Frozen Foods
# 9             Low Fat           FDX25                 Canned
# 11            Low Fat           NCU41     Health and Hygiene
# 13            Low Fat           NCR54              Household
# ...               ...             ...                    ...
# 8512          Regular           FDY33            Snack Foods
# 8515          low fat           FDK38                 Canned
# 8517          low fat           FDG32  Fruits and Vegetables
# 8518          low fat           NCT53     Health and Hygiene
# 8519          low fat           FDN09            Snack Foods
#
#       Outlet Establishment Year Outlet Identifier Outlet Location Type  \
# 0                          2012            OUT049               Tier 1
# 2                          2016            OUT046               Tier 1
# ...

# %%
df.nlargest(5,'Rating')[['Item Identifier','Item Type','Rating','Sales']]
# Out:
#   Item Identifier              Item Type  Rating     Sales
# 0           FDX32  Fruits and Vegetables     5.0  145.4786
# 1           NCB42     Health and Hygiene     5.0  115.3492
# 2           FDR28           Frozen Foods     5.0  165.0210
# 3           FDL50                 Canned     5.0  126.5046
# 4           DRI25            Soft Drinks     5.0   55.1614

# %%
df.groupby('Outlet Identifier')['Sales'].mean().sort_values(ascending=False)
# Out:
# Outlet Identifier
# OUT035    143.122481
# OUT046    142.057387
# OUT018    141.678638
# OUT013    141.425982
# OUT045    140.950248
# OUT010    140.777597
# OUT049    140.297699
# OUT027    139.801791
# OUT019    139.787088
# OUT017    139.421124
# Name: Sales, dtype: float64

# %%
df['Item Type'].value_counts()
# Out:
# Item Type
# Fruits and Vegetables    1232
# Snack Foods              1200
# Household                 910
# Frozen Foods              856
# Dairy                     682
# Canned                    649
# Baking Goods              648
# Health and Hygiene        520
# Soft Drinks               445
# Meat                      425
# Breads                    251
# Hard Drinks               214
# Others                    169
# Starchy Foods             148
# Breakfast                 110
# Seafood                    64
# Name: count, dtype: int64

# %%
df.groupby('Outlet Type')['Rating'].mean().sort_values(ascending=False)
# Out:
# Outlet Type
# Grocery Store        3.985873
# Supermarket Type2    3.971228
# Supermarket Type1    3.963242
# Supermarket Type3    3.952941
# Name: Rating, dtype: float64

# %%
df.groupby('Outlet Identifier')['Item Identifier'].count().sort_values(ascending=False)
# Out:
# Outlet Identifier
# OUT027    935
# OUT013    932
# OUT035    930
# OUT046    930
# OUT049    930
# OUT045    929
# OUT018    928
# OUT017    926
# OUT010    555
# OUT019    528
# Name: Item Identifier, dtype: int64

# %%
df.groupby('Item Identifier')['Item Visibility'].max()
# Out:
# Item Identifier
# DRA12    0.068535
# DRA24    0.069909
# DRA59    0.223985
# DRB01    0.082367
# DRB13    0.011791
#            ...
# NCZ30    0.043828
# NCZ41    0.064786
# NCZ42    0.011352
# NCZ53    0.040970
# NCZ54    0.145952
# Name: Item Visibility, Length: 1559, dtype: float64

# %%
df['Sales Category']=df['Sales'].apply(lambda x : 'High' if x>=200 else'Medium' if 100<=x<=200 else 'Low')

# %%
sales_by_category = df.groupby("Item Type")["Sales"].sum()

percentage = (sales_by_category / sales_by_category.sum()) * 100

percentage.sort_values(ascending=False)
# Out:
# Item Type
# Fruits and Vegetables    14.822903
# Snack Foods              14.599037
# Household                11.315521
# Frozen Foods              9.866082
# Dairy                     8.427896
# Canned                    7.548317
# Baking Goods              6.815012
# Health and Hygiene        5.660888
# Meat                      4.947223
# Soft Drinks               4.869357
# Breads                    2.944135
# Hard Drinks               2.441136
# Others                    1.868373
# Starchy Foods             1.820784
# Breakfast                 1.297906
# Seafood                   0.755431
# Name: Sales, dtype: float64

# %%
df.to_csv("blinkit_cleaned.csv", index=False)
